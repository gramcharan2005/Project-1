# %%
import pandas as pd          # main data tool (like Excel in Python)
import numpy as np           # math & number operations
import matplotlib.pyplot as plt  # basic charts
import seaborn as sns        # nicer looking charts
import warnings

warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)  # show ALL columns
print('All libraries imported successfully!')
# Out:
# All libraries imported successfully!

# %%
df = pd.read_csv('D:\Technocolabs\Pickup Five Cities Datasets\pickup_cq.csv')

# %%
print('Number of rows   :', df.shape[0])  # how many records
print('Number of columns:', df.shape[1])  # how many fields
# Out:
# Number of rows   : 1172703
# Number of columns: 19

# %%
df.head()
# Out:
#    order_id  region_id       city  courier_id     accept_time  \
# 0    483671          3  Chongqing        1518  08-14 07:57:00
# 1   1746131          3  Chongqing        4706  10-09 07:46:00
# 2   2301722          3  Chongqing        4706  10-09 13:57:00
# 3   3788723          3  Chongqing        4706  05-19 08:13:00
# 4    713435          3  Chongqing        4706  05-22 08:16:00
#
#   time_window_start time_window_end        lng       lat  aoi_id  aoi_type  \
# 0    08-14 09:00:00  08-14 11:00:00  106.46877  29.47204     218        14
# 1    10-09 09:00:00  10-09 11:00:00  106.46872  29.47200     218        14
# 2    10-09 13:57:00  10-09 15:57:00  106.46869  29.47191     218        14
# 3    05-19 11:00:00  05-19 13:00:00  106.46878  29.47208     218        14
# 4    05-22 09:00:00  05-22 11:00:00  106.46813  29.47228     218        14
#
#       pickup_time pickup_gps_time  pickup_gps_lng  pickup_gps_lat  \
# 0  08-14 09:38:00             NaN             NaN             NaN
# 1  10-09 09:42:00             NaN             NaN             NaN
# 2  10-09 15:53:00  10-09 15:53:00       106.46821        29.46771
# 3  05-19 11:59:00             NaN             NaN             NaN
# 4  05-22 10:40:00  05-22 10:40:00       106.46827        29.47270
#
#   accept_gps_time  accept_gps_lng  accept_gps_lat    ds
# 0             NaN             NaN             NaN   814
# 1             NaN             NaN             NaN  1009
# 2  10-09 13:56:00       106.46929        29.47231  1009
# 3             NaN             NaN             NaN   519
# 4             NaN             NaN             NaN   522

# %%
print(df.columns.tolist())
# Out:
# ['order_id', 'region_id', 'city', 'courier_id', 'accept_time', 'time_window_start', 'time_window_end', 'lng', 'lat', 'aoi_id', 'aoi_type', 'pickup_time', 'pickup_gps_time', 'pickup_gps_lng', 'pickup_gps_lat', 'accept_gps_time', 'accept_gps_lng', 'accept_gps_lat', 'ds']

# %%
df.dtypes
# Out:
# order_id               int64
# region_id              int64
# city                  object
# courier_id             int64
# accept_time           object
# time_window_start     object
# time_window_end       object
# lng                  float64
# lat                  float64
# aoi_id                 int64
# aoi_type               int64
# pickup_time           object
# pickup_gps_time       object
# pickup_gps_lng       float64
# pickup_gps_lat       float64
# accept_gps_time       object
# accept_gps_lng       float64
# accept_gps_lat       float64
# ds                     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1172703 entries, 0 to 1172702
# Data columns (total 19 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           1172703 non-null  int64
#  1   region_id          1172703 non-null  int64
#  2   city               1172703 non-null  object
#  3   courier_id         1172703 non-null  int64
#  4   accept_time        1172703 non-null  object
#  5   time_window_start  1172703 non-null  object
#  6   time_window_end    1172703 non-null  object
#  7   lng                1172703 non-null  float64
#  8   lat                1172703 non-null  float64
#  9   aoi_id             1172703 non-null  int64
#  10  aoi_type           1172703 non-null  int64
#  11  pickup_time        1172703 non-null  object
#  12  pickup_gps_time    849961 non-null   object
#  13  pickup_gps_lng     849961 non-null   float64
#  14  pickup_gps_lat     849961 non-null   float64
#  15  accept_gps_time    625363 non-null   object
#  16  accept_gps_lng     625363 non-null   float64
#  17  accept_gps_lat     625363 non-null   float64
#  18  ds                 1172703 non-null  int64
# dtypes: float64(6), int64(6), object(7)
# memory usage: 170.0+ MB

# %%
df.describe()
# Out:
#            order_id     region_id    courier_id           lng           lat  \
# count  1.172703e+06  1.172703e+06  1.172703e+06  1.172703e+06  1.172703e+06
# mean   3.080779e+06  6.296789e+01  8.144557e+03  1.069312e+02  2.978241e+01
# std    1.778844e+06  2.717428e+01  4.505008e+03  9.033255e-01  5.330177e-01
# min    1.500000e+01  3.000000e+00  1.000000e+01  1.053727e+02  2.890918e+01
# 25%    1.541344e+06  4.100000e+01  4.172000e+03  1.064630e+02  2.951968e+01
# 50%    3.080762e+06  6.400000e+01  8.238000e+03  1.065138e+02  2.959160e+01
# 75%    4.619964e+06  8.800000e+01  1.190900e+04  1.071025e+02  2.972275e+01
# max    6.161995e+06  1.010000e+02  1.606600e+04  1.096326e+02  3.140580e+01
#
#              aoi_id      aoi_type  pickup_gps_lng  pickup_gps_lat  \
# count  1.172703e+06  1.172703e+06   849961.000000   849961.000000
# mean   1.222426e+04  4.737334e+00      107.013589       29.828223
# std    6.974937e+03  5.724936e+00        0.972882        0.569020
# min    3.000000e+00  0.000000e+00      103.312460       19.991480
# 25%    6.426000e+03  1.000000e+00      106.464800       29.515730
# 50%    1.210100e+04  1.000000e+00      106.526090       29.602310
# 75%    1.803100e+04  1.400000e+01      107.377230       29.846280
# max    2.453000e+04  1.400000e+01      121.192750       39.919080
#
#        accept_gps_lng  accept_gps_lat            ds
# count   625363.000000   625363.000000  1.172703e+06
# mean       107.031439       29.842615  7.617061e+02
# std          0.983292        0.573844  1.725939e+02
# min        104.021400       24.811230  5.010000e+02
# 25%        106.469780       29.503820  6.150000e+02
# 50%        106.526180       29.603480  7.260000e+02
# 75%        107.392130       29.853140  9.170000e+02
# max        121.189760       39.917010  1.031000e+03

# %%
df.isnull().sum()
# Out:
# order_id                  0
# region_id                 0
# city                      0
# courier_id                0
# accept_time               0
# time_window_start         0
# time_window_end           0
# lng                       0
# lat                       0
# aoi_id                    0
# aoi_type                  0
# pickup_time               0
# pickup_gps_time      322742
# pickup_gps_lng       322742
# pickup_gps_lat       322742
# accept_gps_time      547340
# accept_gps_lng       547340
# accept_gps_lat       547340
# ds                        0
# dtype: int64

# %%
missing_pct = (df.isnull().sum() / len(df)) * 100
print(missing_pct.sort_values(ascending=False))
# Out:
# accept_gps_lat       46.673369
# accept_gps_lng       46.673369
# accept_gps_time      46.673369
# pickup_gps_lat       27.521205
# pickup_gps_lng       27.521205
# pickup_gps_time      27.521205
# order_id              0.000000
# aoi_type              0.000000
# pickup_time           0.000000
# aoi_id                0.000000
# region_id             0.000000
# lat                   0.000000
# lng                   0.000000
# time_window_end       0.000000
# time_window_start     0.000000
# accept_time           0.000000
# courier_id            0.000000
# city                  0.000000
# ds                    0.000000
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 4))
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title('Missing Values Heatmap (yellow = missing)')
plt.tight_layout()
plt.show()

# %%
df['has_pickup_gps'] = df['pickup_gps_time'].notna()
df['has_accept_gps'] = df['accept_gps_time'].notna()
print('Rows with pickup GPS :', df['has_pickup_gps'].sum())
print('Rows WITHOUT pickup GPS:', (~df['has_pickup_gps']).sum())
# Out:
# Rows with pickup GPS : 849961
# Rows WITHOUT pickup GPS: 322742

# %%
gps_cols = ['pickup_gps_lng', 'pickup_gps_lat',
            'accept_gps_lng',  'accept_gps_lat']
df[gps_cols] = df[gps_cols].fillna(0.0)

# %%
print(df[gps_cols].isnull().sum())
# Out:
# pickup_gps_lng    0
# pickup_gps_lat    0
# accept_gps_lng    0
# accept_gps_lat    0
# dtype: int64

# %%
df.head()
# Out:
#    order_id  region_id       city  courier_id     accept_time  \
# 0    483671          3  Chongqing        1518  08-14 07:57:00
# 1   1746131          3  Chongqing        4706  10-09 07:46:00
# 2   2301722          3  Chongqing        4706  10-09 13:57:00
# 3   3788723          3  Chongqing        4706  05-19 08:13:00
# 4    713435          3  Chongqing        4706  05-22 08:16:00
#
#   time_window_start time_window_end        lng       lat  aoi_id  aoi_type  \
# 0    08-14 09:00:00  08-14 11:00:00  106.46877  29.47204     218        14
# 1    10-09 09:00:00  10-09 11:00:00  106.46872  29.47200     218        14
# 2    10-09 13:57:00  10-09 15:57:00  106.46869  29.47191     218        14
# 3    05-19 11:00:00  05-19 13:00:00  106.46878  29.47208     218        14
# 4    05-22 09:00:00  05-22 11:00:00  106.46813  29.47228     218        14
#
#       pickup_time pickup_gps_time  pickup_gps_lng  pickup_gps_lat  \
# 0  08-14 09:38:00             NaN         0.00000         0.00000
# 1  10-09 09:42:00             NaN         0.00000         0.00000
# 2  10-09 15:53:00  10-09 15:53:00       106.46821        29.46771
# 3  05-19 11:59:00             NaN         0.00000         0.00000
# 4  05-22 10:40:00  05-22 10:40:00       106.46827        29.47270
#
#   accept_gps_time  accept_gps_lng  accept_gps_lat    ds  has_pickup_gps  \
# 0             NaN         0.00000         0.00000   814           False
# 1             NaN         0.00000         0.00000  1009           False
# 2  10-09 13:56:00       106.46929        29.47231  1009            True
# 3             NaN         0.00000         0.00000   519           False
# 4             NaN         0.00000         0.00000   522            True
#
#    has_accept_gps
# 0           False
# 1           False
# 2            True
# 3           False
# 4           False

# %%
# Step 1 — Reload the original file fresh (resets everything)
df = pd.read_csv('D:\Technocolabs\Pickup Five Cities Datasets\pickup_cq.csv')

# Step 2 — Convert datetime columns (format is MM-DD HH:MM:SS, add year manually)
time_cols = ['accept_time', 'time_window_start', 'time_window_end', 'pickup_time']

for col in time_cols:
    df[col] = pd.to_datetime('2023-' + df[col],
                              format='%Y-%m-%d %H:%M:%S',
                              errors='coerce')

# Step 3 — Verify it worked
print(df[time_cols].dtypes)
print()
print(df['accept_time'].head())
# Out:
# accept_time          datetime64[ns]
# time_window_start    datetime64[ns]
# time_window_end      datetime64[ns]
# pickup_time          datetime64[ns]
# dtype: object
#
# 0   2023-08-14 07:57:00
# 1   2023-10-09 07:46:00
# 2   2023-10-09 13:57:00
# 3   2023-05-19 08:13:00
# 4   2023-05-22 08:16:00
# Name: accept_time, dtype: datetime64[ns]

# %%
# Example: How many minutes from accept to pickup?
df['accept_to_pickup_min'] = (
    (df['pickup_time'] - df['accept_time']).dt.total_seconds() / 60
)
print(df['accept_to_pickup_min'].describe().round(1))
# This shows average, min, max pickup time in minutes
# Out:
# count    1172703.0
# mean         208.5
# std          392.7
# min            0.0
# 25%           61.0
# 50%          113.0
# 75%          186.0
# max        32039.0
# Name: accept_to_pickup_min, dtype: float64

# %%
duplicates = df.duplicated(subset=['order_id'])
print('Number of duplicate rows:', duplicates.sum())
# Out:
# Number of duplicate rows: 0

# %%
before = len(df)
df = df.drop_duplicates(subset=['order_id'], keep='first')
df = df.reset_index(drop=True)   # re-number the rows from 0
after = len(df)
print(f'Rows before: {before:,}')
print(f'Rows after : {after:,}')
print(f'Duplicates removed: {before - after:,}')
# Out:
# Rows before: 1,172,703
# Rows after : 1,172,703
# Duplicates removed: 0

# %%
col = 'accept_to_pickup_min'
Q1 = df[col].quantile(0.25)
Q3 = df[col].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
outliers = (df[col] < lower) | (df[col] > upper)
print(f'Outlier rows found: {outliers.sum():,}')
print(f'Valid range: {lower:.0f} to {upper:.0f} minutes')
# Out:
# Outlier rows found: 126,238
# Valid range: -126 to 374 minutes

# %%
df = df[df['accept_to_pickup_min'] >= 0].reset_index(drop=True)
print('Rows after removing negatives:', len(df))
# Out:
# Rows after removing negatives: 1172703

# %%
df['accept_to_pickup_min'] = df['accept_to_pickup_min'].clip(upper=upper)
print('Max duration after clipping:', df['accept_to_pickup_min'].max())
# Out:
# Max duration after clipping: 373.5

# %%
df['pickup_on_time'] = (
    (df['pickup_time'] >= df['time_window_start']) &
    (df['pickup_time'] <= df['time_window_end'])
)
on_time_pct = df['pickup_on_time'].mean() * 100
print(f'On-time pickup rate: {on_time_pct:.1f}%')
# Out:
# On-time pickup rate: 76.6%

# %%
df['accept_hour']  = df['accept_time'].dt.hour    # 0 to 23
df['accept_day']   = df['accept_time'].dt.day     # 1 to 31
df['accept_month'] = df['accept_time'].dt.month   # 1 to 12
print(df[['accept_time', 'accept_hour', 'accept_day', 'accept_month']].head(3))
# Out:
#           accept_time  accept_hour  accept_day  accept_month
# 0 2023-08-14 07:57:00            7          14             8
# 1 2023-10-09 07:46:00            7           9            10
# 2 2023-10-09 13:57:00           13           9            10

# %%
def time_of_day(hour):
    if   0 <= hour < 6:   return 'Night'
    elif 6 <= hour < 12:  return 'Morning'
    elif 12 <= hour < 17: return 'Afternoon'
    elif 17 <= hour < 21: return 'Evening'
    else:                  return 'Night'
df['time_of_day'] = df['accept_hour'].apply(time_of_day)
print(df['time_of_day'].value_counts())
print(df['time_of_day'].value_counts().sum())
# Out:
# time_of_day
# Morning      878293
# Afternoon    289420
# Evening        4825
# Night           165
# Name: count, dtype: int64
# 1172703

# %%
df['window_duration_min'] = (
    (df['time_window_end'] - df['time_window_start']).dt.total_seconds() / 60
)
print(df['window_duration_min'].value_counts().head())
# Out:
# window_duration_min
# 120.0    1093454
# 60.0       72271
# 899.0       2533
# 489.0         18
# 490.0         15
# Name: count, dtype: int64

# %%
# Cell 11a — Distribution of pickup duration
plt.figure(figsize=(8, 4))
df['accept_to_pickup_min'].plot(kind='hist', bins=50, color='steelblue',
                                edgecolor='white')
plt.title('How long does pickup take? (minutes)')
plt.xlabel('Minutes from Accept to Pickup')
plt.ylabel('Number of Orders')
plt.tight_layout()
plt.show()
# Most orders should be picked up in 30-120 minutes

# %%
# Cell 11b — Orders by hour of day (busy hours)
plt.figure(figsize=(10, 4))
df['accept_hour'].value_counts().sort_index().plot(kind='bar',
    color='coral', edgecolor='white')
plt.title('Number of Orders by Hour of Day')
plt.xlabel('Hour (0 = midnight, 12 = noon)')
plt.ylabel('Number of Orders')
plt.tight_layout()
plt.show()

# %%
# Cell 11c — On-time vs Late pickup (pie chart)
plt.figure(figsize=(5, 5))
df['pickup_on_time'].value_counts().plot(kind='pie',
    labels=['On Time', 'Late'],
    autopct='%1.1f%%',
    colors=['mediumseagreen', 'salmon'])
plt.title('Pickup On-Time Rate')
plt.ylabel('')
plt.show()

# %%
# Cell 11d — Courier performance: top 10 by order count
top_couriers = df.groupby('courier_id').agg(
    total_orders = ('order_id', 'count'),
    avg_duration = ('accept_to_pickup_min', 'mean'),
    on_time_rate = ('pickup_on_time', 'mean')
).sort_values('total_orders', ascending=False).head(10)
print(top_couriers.round(2))
# Out:
#             total_orders  avg_duration  on_time_rate
# courier_id
# 11113               8261        157.45          0.90
# 4172                7433        118.05          0.67
# 15344               7257        145.92          0.72
# 13994               7143        133.02          0.65
# 10674               7089        139.20          0.82
# 8277                7024        116.03          0.67
# 2270                7012        149.00          0.80
# 2615                6965        108.56          0.67
# 6057                6951        134.26          0.73
# 12907               6903        147.31          0.83

# %%
print('Final dataset shape:', df.shape)
print()
print('Missing values left:')
print(df.isnull().sum()[df.isnull().sum() > 0])
print()
print('New columns created:')
new_cols = ['has_pickup_gps', 'has_accept_gps', 'accept_to_pickup_min',
            'pickup_on_time', 'accept_hour', 'accept_day', 'accept_month',
            'time_of_day', 'window_duration_min']
print(new_cols)
# Out:
# Final dataset shape: (1172703, 26)
#
# Missing values left:
# pickup_gps_time    322742
# pickup_gps_lng     322742
# pickup_gps_lat     322742
# accept_gps_time    547340
# accept_gps_lng     547340
# accept_gps_lat     547340
# dtype: int64
#
# New columns created:
# ['has_pickup_gps', 'has_accept_gps', 'accept_to_pickup_min', 'pickup_on_time', 'accept_hour', 'accept_day', 'accept_month', 'time_of_day', 'window_duration_min']

# %%
# Check all text columns and their unique values
text_cols = df.select_dtypes(include='object').columns.tolist()
print('Text columns:', text_cols)
print()

for col in text_cols:
    print(f'--- {col} ---')
    print(df[col].value_counts())
    print()
# Out:
# Text columns: ['city', 'pickup_gps_time', 'accept_gps_time', 'time_of_day']
#
# --- city ---
# city
# Chongqing    1172703
# Name: count, dtype: int64
#
# --- pickup_gps_time ---
# pickup_gps_time
# 06-27 10:39:00    37
# 07-06 10:30:00    33
# 06-23 10:01:00    33
# 06-19 10:36:00    32
# 06-20 10:24:00    32
#                   ..
# 09-01 17:04:00     1
# 07-29 18:31:00     1
# 09-01 13:23:00     1
# 09-14 12:58:00     1
# 07-29 14:03:00     1
# Name: count, Length: 121496, dtype: int64
#
# --- accept_gps_time ---
# accept_gps_time
# 06-22 07:42:00    61
# 06-23 08:03:00    60
# 06-20 08:00:00    59
# 06-21 08:07:00    58
# 06-25 07:50:00    57
#                   ..
# 10-21 13:29:00     1
# 08-11 13:01:00     1
# 05-25 14:46:00     1
# 10-31 07:07:00     1
# 08-15 14:21:00     1
# Name: count, Length: 104682, dtype: int64
#
# --- time_of_day ---
# time_of_day
# Morning      878293
# Afternoon    289420
# Evening        4825
# Night           165
# Name: count, dtype: int64

# %%
for col in text_cols:
    df[col] = df[col].str.strip()        # remove spaces before/after
    df[col] = df[col].str.title()        # Capitalize First Letter
    df[col] = df[col].str.replace(r'\s+', ' ', regex=True)  # remove double spaces

print('Text columns cleaned!')
print(df['city'].value_counts())
# Out:
# Text columns cleaned!
# city
# Chongqing    1172703
# Name: count, dtype: int64

# %%
print(df[df['aoi_type'] == 0]['aoi_type'].count())
# Out:
# 34877

# %%
# Cell 12b — Save cleaned data to a new CSV file
df.to_csv('pickup_cq_cleaned.csv', index=False)
print('File saved as: pickup_cq_cleaned.csv')
print(f'Total rows saved: {len(df):,}')
# Out:
# File saved as: pickup_cq_cleaned.csv
# Total rows saved: 1,172,703
