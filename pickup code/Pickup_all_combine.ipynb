# %%
import pandas as pd

df1 = pd.read_csv(r'C:\Users\X1 Carbon\OneDrive\Desktop\pickup csv\pickup_cq_cleaned.csv')
df2 = pd.read_csv(r'C:\Users\X1 Carbon\OneDrive\Desktop\pickup csv\pickup_hz_cleaned.csv')
df3 = pd.read_csv(r'C:\Users\X1 Carbon\OneDrive\Desktop\pickup csv\pickup_jl_cleaned.csv')
df4 = pd.read_csv(r'C:\Users\X1 Carbon\OneDrive\Desktop\pickup csv\pickup_sh_cleaned.csv')
df5 = pd.read_csv(r'C:\Users\X1 Carbon\OneDrive\Desktop\pickup csv\pickup_yt_cleaned.csv')

# Combine
df_combined = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

print('Total rows:', len(df_combined))
print('Total columns:', len(df_combined.columns))

df_combined.to_csv(r'C:\Users\X1 Carbon\OneDrive\Desktop\pickup csv\pickup_all_combined.csv', index=False)
print('Saved ✅')
# Out:
# Total rows: 6034157
# Total columns: 26
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 15
#      12 print('Total rows:', len(df_combined))
#      13 print('Total columns:', len(df_combined.columns))
# ---> 15 df_combined.to_csv(r'C:\Users\X1 Carbon\OneDrive\Desktop\pickup csv\pickup_all_combined.csv', index=False)
#      16 print('Saved ✅')
#
# File D:\anaconda\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
