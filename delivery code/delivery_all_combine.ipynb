# %%
import pandas as pd

df1 = pd.read_csv(r'C:\Users\X1 Carbon\OneDrive\Desktop\delivery excel\delivery_cq_cleaned.csv')
df2 = pd.read_csv(r'C:\Users\X1 Carbon\OneDrive\Desktop\delivery excel\delivery_hz_cleaned.csv')
df3 = pd.read_csv(r'C:\Users\X1 Carbon\OneDrive\Desktop\delivery excel\delivery_jl_cleaned.csv')
df4 = pd.read_csv(r'C:\Users\X1 Carbon\OneDrive\Desktop\delivery excel\delivery_sh_cleaned.csv')
df5 = pd.read_csv(r'C:\Users\X1 Carbon\OneDrive\Desktop\delivery excel\delivery_yt_cleaned.csv')

# Combine
df_combined = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

print('Total rows:', len(df_combined))
print('Total columns:', len(df_combined.columns))

df_combined.to_csv(r'C:\Users\X1 Carbon\OneDrive\Desktop\delivery excel\all_combined.csv', index=False)
print('Saved ✅')
# Out:
# Total rows: 4133328
# Total columns: 27
# Saved ✅
