# %%
import pandas as pd # main data tool (like Excel in Python)
import numpy as np # math & number operations
import matplotlib.pyplot as plt # basic charts
import seaborn as sns # nicer looking charts
import warnings
warnings.filterwarnings('ignore') # hide unnecessary warning messages
pd.set_option('display.max_columns', None) # show ALL columns
print('All libraries imported successfully!')
# Out:
# All libraries imported successfully!

# %%
df = pd.read_csv('D:\Technocolabs\Delivery Five Cities Datasets\delivery_cq.csv') # reads the file
print('File loaded!')
print('Number of rows :', df.shape[0]) # how many records
print('Number of columns :', df.shape[1]) # how many field
# Out:
# File loaded!
# Number of rows : 931351
# Number of columns : 17

# %%
df.head()
# Out:
#    order_id  region_id       city  courier_id        lng       lat  aoi_id  \
# 0   2031782         10  Chongqing          73  108.71571  30.90228      50
# 1   4285071         10  Chongqing        3605  108.71639  30.90269      50
# 2   4056800         10  Chongqing        3605  108.71645  30.90259      50
# 3   3589481         10  Chongqing        3605  108.71650  30.90347      50
# 4   2752329         10  Chongqing        3605  108.71608  30.90409      50
#
#    aoi_type     accept_time accept_gps_time  accept_gps_lng  accept_gps_lat  \
# 0        14  10-22 10:26:00  10-22 10:26:00       108.71826        30.95587
# 1        14  09-07 10:13:00  09-07 10:13:00       108.71791        30.95635
# 2        14  06-26 09:49:00  06-26 09:49:00       108.71798        30.95635
# 3        14  09-11 11:01:00  09-11 11:01:00       108.71823        30.95596
# 4        14  10-01 09:52:00  10-01 09:52:00       108.71820        30.95598
#
#     delivery_time delivery_gps_time  delivery_gps_lng  delivery_gps_lat    ds
# 0  10-22 17:04:00    10-22 17:04:00         108.66361          30.96702  1022
# 1  09-09 15:44:00    09-09 15:44:00         108.71644          30.90266   907
# 2  06-27 16:03:00    06-27 16:03:00         108.71647          30.90251   626
# 3  09-13 17:14:00    09-13 17:14:00         108.71650          30.90341   911
# 4  10-01 18:30:00    10-01 18:30:00         108.71413          30.90397  1001

# %%
print('Column names:')
print(df.columns.tolist())
# Out:
# Column names:
# ['order_id', 'region_id', 'city', 'courier_id', 'lng', 'lat', 'aoi_id', 'aoi_type', 'accept_time', 'accept_gps_time', 'accept_gps_lng', 'accept_gps_lat', 'delivery_time', 'delivery_gps_time', 'delivery_gps_lng', 'delivery_gps_lat', 'ds']

# %%
df.dtypes
# Out:
# order_id               int64
# region_id              int64
# city                  object
# courier_id             int64
# lng                  float64
# lat                  float64
# aoi_id                 int64
# aoi_type               int64
# accept_time           object
# accept_gps_time       object
# accept_gps_lng       float64
# accept_gps_lat       float64
# delivery_time         object
# delivery_gps_time     object
# delivery_gps_lng     float64
# delivery_gps_lat     float64
# ds                     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 931351 entries, 0 to 931350
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   order_id           931351 non-null  int64
#  1   region_id          931351 non-null  int64
#  2   city               931351 non-null  object
#  3   courier_id         931351 non-null  int64
#  4   lng                931351 non-null  float64
#  5   lat                931351 non-null  float64
#  6   aoi_id             931351 non-null  int64
#  7   aoi_type           931351 non-null  int64
#  8   accept_time        931351 non-null  object
#  9   accept_gps_time    931351 non-null  object
#  10  accept_gps_lng     931351 non-null  float64
#  11  accept_gps_lat     931351 non-null  float64
#  12  delivery_time      931351 non-null  object
#  13  delivery_gps_time  931351 non-null  object
#  14  delivery_gps_lng   931351 non-null  float64
#  15  delivery_gps_lat   931351 non-null  float64
#  16  ds                 931351 non-null  int64
# dtypes: float64(6), int64(6), object(5)
# memory usage: 120.8+ MB

# %%
df.describe()
# Out:
#            order_id      region_id     courier_id            lng  \
# count  9.313510e+05  931351.000000  931351.000000  931351.000000
# mean   2.258684e+06     120.010241    2426.110193     106.552007
# std    1.303291e+06      40.521178    1393.778785       0.364687
# min    0.000000e+00      10.000000       2.000000     102.472090
# 25%    1.130730e+06     105.000000    1289.000000     106.474420
# 50%    2.259722e+06     132.000000    2327.000000     106.525440
# 75%    3.386908e+06     150.000000    3688.000000     106.569390
# max    4.514656e+06     166.000000    4872.000000     116.406090
#
#                  lat         aoi_id       aoi_type  accept_gps_lng  \
# count  931351.000000  931351.000000  931351.000000   931351.000000
# mean       29.616572   30141.530239       4.120045      106.552864
# std         0.262483   17063.058600       5.366331        0.357928
# min        28.470950       0.000000       0.000000      105.627910
# 25%        29.521680   15546.000000       1.000000      106.482810
# 50%        29.579710   30433.000000       1.000000      106.518480
# 75%        29.638310   44298.000000       4.000000      106.578300
# max        39.911980   60148.000000      15.000000      120.038410
#
#        accept_gps_lat  delivery_gps_lng  delivery_gps_lat             ds
# count   931351.000000     931351.000000     931351.000000  931351.000000
# mean        29.613112        106.548423         29.615214     806.835567
# std          0.248328          0.705113          0.307303     182.621005
# min         29.043410         -0.000080         -0.000080     501.000000
# 25%         29.509480        106.474410         29.521330     621.000000
# 50%         29.578290        106.525240         29.579460     818.000000
# 75%         29.629780        106.569440         29.638260    1009.000000
# max         31.175790        120.821570         39.911990    1031.000000

# %%
df.isnull().sum()
# Out:
# order_id             0
# region_id            0
# city                 0
# courier_id           0
# lng                  0
# lat                  0
# aoi_id               0
# aoi_type             0
# accept_time          0
# accept_gps_time      0
# accept_gps_lng       0
# accept_gps_lat       0
# delivery_time        0
# delivery_gps_time    0
# delivery_gps_lng     0
# delivery_gps_lat     0
# ds                   0
# dtype: int64

# %%
missing_pct = (df.isnull().sum() / len(df)) * 100
print(missing_pct.sort_values(ascending=False))
# Out:
# order_id             0.0
# accept_gps_time      0.0
# delivery_gps_lat     0.0
# delivery_gps_lng     0.0
# delivery_gps_time    0.0
# delivery_time        0.0
# accept_gps_lat       0.0
# accept_gps_lng       0.0
# accept_time          0.0
# region_id            0.0
# aoi_type             0.0
# aoi_id               0.0
# lat                  0.0
# lng                  0.0
# courier_id           0.0
# city                 0.0
# ds                   0.0
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 4))
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title('Missing Values Heatmap (yellow = missing)')
plt.tight_layout()
plt.show()

# %%
df.isnull().sum().sum() == 0, 'Unexpected missing values found!'
print('Confirmed: No missing values in delivery_cq dataset.')
# Out:
# Confirmed: No missing values in delivery_cq dataset.

# %%
df['gps_synced_accept'] = df['accept_time'] == df['accept_gps_time']
df['gps_synced_delivery'] = df['delivery_time'] == df['delivery_gps_time']

# %%
df.head() #check last 2 columns we added just now
# Out:
#    order_id  region_id       city  courier_id        lng       lat  aoi_id  \
# 0   2031782         10  Chongqing          73  108.71571  30.90228      50
# 1   4285071         10  Chongqing        3605  108.71639  30.90269      50
# 2   4056800         10  Chongqing        3605  108.71645  30.90259      50
# 3   3589481         10  Chongqing        3605  108.71650  30.90347      50
# 4   2752329         10  Chongqing        3605  108.71608  30.90409      50
#
#    aoi_type     accept_time accept_gps_time  accept_gps_lng  accept_gps_lat  \
# 0        14  10-22 10:26:00  10-22 10:26:00       108.71826        30.95587
# 1        14  09-07 10:13:00  09-07 10:13:00       108.71791        30.95635
# 2        14  06-26 09:49:00  06-26 09:49:00       108.71798        30.95635
# 3        14  09-11 11:01:00  09-11 11:01:00       108.71823        30.95596
# 4        14  10-01 09:52:00  10-01 09:52:00       108.71820        30.95598
#
#     delivery_time delivery_gps_time  delivery_gps_lng  delivery_gps_lat    ds  \
# 0  10-22 17:04:00    10-22 17:04:00         108.66361          30.96702  1022
# 1  09-09 15:44:00    09-09 15:44:00         108.71644          30.90266   907
# 2  06-27 16:03:00    06-27 16:03:00         108.71647          30.90251   626
# 3  09-13 17:14:00    09-13 17:14:00         108.71650          30.90341   911
# 4  10-01 18:30:00    10-01 18:30:00         108.71413          30.90397  1001
#
#    gps_synced_accept  gps_synced_delivery
# 0               True                 True
# 1               True                 True
# 2               True                 True
# 3               True                 True
# 4               True                 True

# %%
print('GPS synced at accept :', df['gps_synced_accept'].sum())
print('GPS synced at delivery :', df['gps_synced_delivery'].sum())
# Out:
# GPS synced at accept : 931351
# GPS synced at delivery : 931351

# %%
print(type(df['accept_time'][0])) # will show <class 'str'> = text
print(df['accept_time'][0]) # shows: 10-22 10:26:00
# Out:
# <class 'str'>
# 10-22 10:26:00

# %%
time_cols = ['accept_time', 'accept_gps_time',
'delivery_time', 'delivery_gps_time']
for col in time_cols:
    df[col] = pd.to_datetime('2023-' + df[col],
    format='%Y-%m-%d %H:%M:%S',
    errors='coerce') # bad values → NaT

# %%
print('After conversion:')
print(df[time_cols].dtypes)
# Out:
# After conversion:
# accept_time          datetime64[ns]
# accept_gps_time      datetime64[ns]
# delivery_time        datetime64[ns]
# delivery_gps_time    datetime64[ns]
# dtype: object

# %%
# Example: How many minutes from accept to delivery?
df['accept_to_delivery_min'] = (
(df['delivery_time'] - df['accept_time']).dt.total_seconds() / 60)

# %%
df.head()
# Out:
#    order_id  region_id       city  courier_id        lng       lat  aoi_id  \
# 0   2031782         10  Chongqing          73  108.71571  30.90228      50
# 1   4285071         10  Chongqing        3605  108.71639  30.90269      50
# 2   4056800         10  Chongqing        3605  108.71645  30.90259      50
# 3   3589481         10  Chongqing        3605  108.71650  30.90347      50
# 4   2752329         10  Chongqing        3605  108.71608  30.90409      50
#
#    aoi_type         accept_time     accept_gps_time  accept_gps_lng  \
# 0        14 2023-10-22 10:26:00 2023-10-22 10:26:00       108.71826
# 1        14 2023-09-07 10:13:00 2023-09-07 10:13:00       108.71791
# 2        14 2023-06-26 09:49:00 2023-06-26 09:49:00       108.71798
# 3        14 2023-09-11 11:01:00 2023-09-11 11:01:00       108.71823
# 4        14 2023-10-01 09:52:00 2023-10-01 09:52:00       108.71820
#
#    accept_gps_lat       delivery_time   delivery_gps_time  delivery_gps_lng  \
# 0        30.95587 2023-10-22 17:04:00 2023-10-22 17:04:00         108.66361
# 1        30.95635 2023-09-09 15:44:00 2023-09-09 15:44:00         108.71644
# 2        30.95635 2023-06-27 16:03:00 2023-06-27 16:03:00         108.71647
# 3        30.95596 2023-09-13 17:14:00 2023-09-13 17:14:00         108.71650
# 4        30.95598 2023-10-01 18:30:00 2023-10-01 18:30:00         108.71413
#
#    delivery_gps_lat    ds  gps_synced_accept  gps_synced_delivery  \
# 0          30.96702  1022               True                 True
# 1          30.90266   907               True                 True
# 2          30.90251   626               True                 True
# 3          30.90341   911               True                 True
# 4          30.90397  1001               True                 True
#
#    accept_to_delivery_min
# 0                   398.0
# 1                  3211.0
# 2                  1814.0
# 3                  3253.0
# 4                   518.0

# %%
print(df['accept_to_delivery_min'].describe().round(1))
# Out:
# count    931351.0
# mean        308.8
# std        1336.0
# min     -421417.0
# 25%          83.0
# 50%         151.0
# 75%         256.0
# max      128630.0
# Name: accept_to_delivery_min, dtype: float64

# %%
duplicates = df.duplicated(subset=['order_id'])
print('Number of duplicate rows:', duplicates.sum())
# Out:
# Number of duplicate rows: 0

# %%
before = len(df)
df = df.drop_duplicates(subset=['order_id'], keep='first')
df = df.reset_index(drop=True) # re-number the rows from 0
after = len(df)
print(f'Rows before: {before:,}')
print(f'Rows after : {after:,}')
print(f'Duplicates removed: {before - after:,}')
# Out:
# Rows before: 931,351
# Rows after : 931,351
# Duplicates removed: 0

# %%
print(f'Rows before: {before:,}')
print(f'Rows after : {after:,}')
print(f'Duplicates removed: {before - after:,}')
# Out:
# Rows before: 931,351
# Rows after : 931,351
# Duplicates removed: 0

# %%
col = 'accept_to_delivery_min'
Q1 = df[col].quantile(0.25)
Q3 = df[col].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
outliers = (df[col] < lower) | (df[col] > upper)
print(f'Outlier rows found: {outliers.sum():,}')
print(f'Valid range: {lower:.0f} to {upper:.0f} minutes')
# Out:
# Outlier rows found: 85,680
# Valid range: -176 to 516 minutes

# %%
df = df[df['accept_to_delivery_min'] >= 0].reset_index(drop=True)
print('Rows after removing negatives:', len(df))
# Out:
# Rows after removing negatives: 931348

# %%
print('Number of rows :', df.shape[0]) # how many records
print('Number of columns :', df.shape[1]) # how many field
# Out:
# Number of rows : 931348

# %%
df['accept_to_delivery_min'] = df['accept_to_delivery_min'].clip(upper=upper)
print('Max duration after clipping:', df['accept_to_delivery_min'].max())
# Out:
# Max duration after clipping: 515.5

# %%
# Cell 10a — Extract hour, day, month from accept_time
df['accept_hour'] = df['accept_time'].dt.hour # 0 to 23
df['accept_day'] = df['accept_time'].dt.day # 1 to 31
df['accept_month'] = df['accept_time'].dt.month # 1 to 12
print(df[['accept_time','accept_hour','accept_day','accept_month']].head(3))
# Cell 10b — Group hour into time-of-day buckets
def time_of_day(hour):
    if 0 <= hour < 6: return 'Night'
    elif 6 <= hour < 12: return 'Morning'
    elif 12 <= hour < 17: return 'Afternoon'
    elif 17 <= hour < 21: return 'Evening'
    else: return 'Night'
df['time_of_day'] = df['accept_hour'].apply(time_of_day)
print(df['time_of_day'].value_counts())
# Out:
#           accept_time  accept_hour  accept_day  accept_month
# 0 2023-10-22 10:26:00           10          22            10
# 1 2023-09-07 10:13:00           10           7             9
# 2 2023-06-26 09:49:00            9          26             6
# time_of_day
# Afternoon    554649
# Morning      345595
# Evening       29497
# Night          1607
# Name: count, dtype: int64

# %%
df['gps_drift'] = ((
(df['delivery_gps_lng'] - df['accept_gps_lng'])**2 +
(df['delivery_gps_lat'] - df['accept_gps_lat'])**2
) ** 0.5)
print(df['gps_drift'].describe().round(4))
# Out:
# count    931348.0000
# mean          0.0335
# std           0.6334
# min           0.0000
# 25%           0.0132
# 50%           0.0233
# 75%           0.0357
# max         110.7040
# Name: gps_drift, dtype: float64

# %%
df['delivery_speed_proxy'] = df['gps_drift'] / (df['accept_to_delivery_min'] + 1)
print('Speed proxy stats:')
print(df['delivery_speed_proxy'].describe().round(4))
# Out:
# Speed proxy stats:
# count    931348.0000
# mean          0.0005
# std           0.0120
# min           0.0000
# 25%           0.0001
# 50%           0.0002
# 75%           0.0003
# max           6.4999
# Name: delivery_speed_proxy, dtype: float64

# %%
df['delivery_month'] = df['delivery_time'].dt.month
print(df['delivery_month'].value_counts().sort_index())
# Out:
# delivery_month
# 5     125087
# 6     141048
# 7     126376
# 8     122399
# 9     138677
# 10    276989
# 11       760
# 12        12
# Name: count, dtype: int64

# %%
# Cell 11a — Distribution of delivery duration
plt.figure(figsize=(8, 4))
df['accept_to_delivery_min'].plot(kind='hist', bins=50, color='steelblue',
edgecolor='white')
plt.title('How long does delivery take? (minutes)')
plt.xlabel('Minutes from Accept to Delivery')
plt.ylabel('Number of Orders')
plt.tight_layout()
plt.show()
# Most orders should be delivered in 83–256 minutes (IQR range)
# Cell 11b — Orders by hour of day (busy hours)
plt.figure(figsize=(10, 4))
df['accept_hour'].value_counts().sort_index().plot(
kind='bar', color='coral', edgecolor='white')
plt.title('Number of Orders by Hour of Day')
plt.xlabel('Hour (0 = midnight, 12 = noon)')
plt.ylabel('Number of Orders')
plt.tight_layout()
plt.show()
# Expect a big spike in Afternoon (12-17) hours
# Cell 11c — GPS drift distribution (delivery vs accept location)
plt.figure(figsize=(8, 4))
df['gps_drift'].plot(kind='hist', bins=60, color='mediumpurple',
edgecolor='white')
plt.title('GPS Drift (Accept vs Delivery Location)')
plt.xlabel('Euclidean GPS Drift')
plt.ylabel('Number of Orders')
plt.tight_layout()
plt.show()
# Cell 11d — Courier performance: top 10 by order count
top_couriers = df.groupby('courier_id').agg(
total_orders = ('order_id', 'count'),
avg_duration = ('accept_to_delivery_min', 'mean'),
avg_gps_drift = ('gps_drift', 'mean')
).sort_values('total_orders', ascending=False).head(10)
print(top_couriers.round(2))
# Out:
#             total_orders  avg_duration  avg_gps_drift
# courier_id
# 2520                5205        156.94           0.01
# 3000                4961        182.49           0.04
# 660                 4812        174.68           0.04
# 936                 4775        170.29           0.04
# 3689                4763        194.81           0.05
# 4183                4555        222.88           0.02
# 2505                4499        214.94           0.05
# 3083                4466        153.44           0.03
# 3029                4408        193.47           0.05
# 3398                4402        174.96           0.04

# %%
print('Final dataset shape:', df.shape)
print()
print('Missing values left:')
print(df.isnull().sum()[df.isnull().sum() > 0])
print()
print('New columns created:')
new_cols = ['gps_synced_accept', 'gps_synced_delivery',
'accept_to_delivery_min', 'accept_hour', 'accept_day',
'accept_month', 'time_of_day', 'gps_drift',
'delivery_speed_proxy', 'delivery_month']
print(new_cols)
# Out:
# Final dataset shape: (931348, 27)
#
# Missing values left:
# Series([], dtype: int64)
#
# New columns created:
# ['gps_synced_accept', 'gps_synced_delivery', 'accept_to_delivery_min', 'accept_hour', 'accept_day', 'accept_month', 'time_of_day', 'gps_drift', 'delivery_speed_proxy', 'delivery_month']

# %%
df.to_csv('delivery_cq_cleaned.csv', index=False)
print('File saved as: delivery_cq_cleaned.csv')
print(f'Total rows saved: {len(df):,}')
# Out:
# File saved as: delivery_cq_cleaned.csv
# Total rows saved: 931,348
